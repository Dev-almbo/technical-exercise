# %% [markdown]
# # EDA

# %%
import sys

sys.path.append("../")
from pathlib import Path

from src.train.preprocessing import load_json, preprocess_data
from src.train.utils import _read_yaml_config

# %%
# read train config
config_path = Path("..", "pipelines", "training", "config.yaml")
config = _read_yaml_config(config_path)
data_dir_raw = config["data_dir_raw"]["path"]
data_dir_processed = config["data_dir_processed"]["path"]
source_data = config["source_data"]["path"]

# %%
reviews = load_json(data_dir_raw, source_data)

# %%
reviews = preprocess_data(reviews)

# %%
# check for nulls
print(reviews.isnull().sum())

# %%
# checkout initial formats of the text:

len(reviews["text"].iloc[0])

# %%
reviews.rating.value_counts()
